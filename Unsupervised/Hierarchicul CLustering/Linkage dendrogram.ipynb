# %% [markdown]
# ## LINKAGE

# %% [markdown]
# ## NP RANDOM DATA

# %% [markdown]
# TYPES of LINKAGE

# %% [markdown]
# WARD - Reducing Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram , linkage



np.random.seed(0)

X = np.random.randn(10 , 2)

X
# Out:
# array([[ 1.76405235,  0.40015721],
#        [ 0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788],
#        [ 0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ],
#        [ 0.14404357,  1.45427351],
#        [ 0.76103773,  0.12167502],
#        [ 0.44386323,  0.33367433],
#        [ 1.49407907, -0.20515826],
#        [ 0.3130677 , -0.85409574]])

# %%
Z = linkage(X , method='ward')
Z
# Out:
# array([[ 3.        ,  6.        ,  0.3320945 ,  2.        ],
#        [ 4.        ,  7.        ,  0.5524637 ,  2.        ],
#        [ 0.        ,  8.        ,  0.66279136,  2.        ],
#        [10.        , 12.        ,  1.10537481,  4.        ],
#        [ 1.        ,  5.        ,  1.14694608,  2.        ],
#        [ 9.        , 11.        ,  1.42549247,  3.        ],
#        [ 2.        , 13.        ,  1.51181476,  5.        ],
#        [15.        , 16.        ,  2.23920573,  8.        ],
#        [14.        , 17.        ,  3.57465643, 10.        ]])

# %%
plt.figure(figsize = (10,6))

dendrogram(Z)

plt.title("Dendrogram Agglomerative Clustering")

plt.xlabel('Sample TExt')
plt.ylabel('Distance')

plt.show()

# %% [markdown]
# SINGlE - MINIMUM DISTANCE

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram , linkage



np.random.seed(0)

X = np.random.randn(10 , 2)

Z = linkage(X , method='single')
plt.figure(figsize = (10,6))

dendrogram(Z)

plt.title("Dendrogram Agglomerative Clustering")

plt.xlabel('Sample TExt')
plt.ylabel('Distance')

plt.show()

# %% [markdown]
# COMPLETE  - MAX DISTANCE

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram , linkage



np.random.seed(0)

X = np.random.randn(10 , 2)

Z = linkage(X , method='complete')
plt.figure(figsize = (10,6))

dendrogram(Z)

plt.title("Dendrogram Agglomerative Clustering")

plt.xlabel('Sample TExt')
plt.ylabel('Distance')

plt.show()

# %% [markdown]
# AVERGAE

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram , linkage



np.random.seed(0)

X = np.random.randn(10 , 2)

Z = linkage(X , method='average')
plt.figure(figsize = (10,6))

dendrogram(Z)

plt.title("Dendrogram Agglomerative Clustering")

plt.xlabel('Sample TExt')
plt.ylabel('Distance')

plt.show()

# %% [markdown]
# CENTROID - uses WCSS internally

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram , linkage



np.random.seed(0)

X = np.random.randn(10 , 2)

Z = linkage(X , method='centroid')
plt.figure(figsize = (10,6))

dendrogram(Z)

plt.title("Dendrogram Agglomerative Clustering")

plt.xlabel('Sample TExt')
plt.ylabel('Distance')

plt.show()

# %% [markdown]
# ## MAKE BLOBS DATASET

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram , linkage


X , _ = make_blobs(n_samples=100 , centers=4 , cluster_std=0.60 , random_state = 0)

Z = linkage(X , method = 'ward')

plt.figure(figsize = (10,6))
dendrogram(Z)

plt.xticks(rotation = 90)

plt.title("dendrogram for hierarchical clustering")

plt.xlabel('Sample text')
plt.ylabel('Distance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram , linkage


X , _ = make_blobs(n_samples=100 , centers=4 , cluster_std=0.60 , random_state = 0)

Z = linkage(X , method = 'single')

plt.figure(figsize = (10,6))
dendrogram(Z)

plt.xticks(rotation = 90)

plt.title("dendrogram for hierarchical clustering")

plt.xlabel('Sample text')
plt.ylabel('Distance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram , linkage


X , _ = make_blobs(n_samples=100 , centers=4 , cluster_std=0.60 , random_state = 0)

Z = linkage(X , method = 'complete')

plt.figure(figsize = (10,6))
dendrogram(Z)

plt.xticks(rotation = 90)

plt.title("dendrogram for hierarchical clustering")

plt.xlabel('Sample text')
plt.ylabel('Distance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram , linkage


X , _ = make_blobs(n_samples=100 , centers=4 , cluster_std=0.60 , random_state = 0)

Z = linkage(X , method = 'centroid')

plt.figure(figsize = (10,6))
dendrogram(Z)

plt.xticks(rotation = 90)

plt.title("dendrogram for hierarchical clustering")

plt.xlabel('Sample text')
plt.ylabel('Distance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram , linkage


X , _ = make_blobs(n_samples=100 , centers=4 , cluster_std=0.60 , random_state = 0)

Z = linkage(X , method = 'average')

plt.figure(figsize = (10,6))
dendrogram(Z)

plt.xticks(rotation = 90)

plt.title("dendrogram for hierarchical clustering")

plt.xlabel('Sample text')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ###  EVALUATE KMEANS Blob Dataset

# %%
from sklearn.cluster import KMeans , AgglomerativeClustering

from sklearn.metrics import silhouette_score , calinski_harabasz_score , davies_bouldin_score

n_clusters = 4

kmeans = KMeans(n_clusters  = n_clusters , random_state = 42)
kmeans_labels = kmeans.fit_predict(X)

agg_cluster = AgglomerativeClustering(n_clusters  = n_clusters , linkage = 'ward')
agg_labels = agg_cluster.fit_predict(X)

kmeans_silhoutte = silhouette_score(X , kmeans_labels)
kmeans_cainski_harabasz = calinski_harabasz_score(X , kmeans_labels)
kmeans_davies_bouldin = davies_bouldin_score(X,kmeans_labels)

agg_silhoutte = silhouette_score(X , agg_labels)
agg_cainski_harabasz = calinski_harabasz_score(X , agg_labels)
agg_davies_bouldin = davies_bouldin_score(X,agg_labels)


print('Evaluation criteria for Kmeans:')
print('kmeans_silhoutte:' , kmeans_silhoutte)
print('kmeans_cainski_harabasz:' , kmeans_cainski_harabasz)
print('kmeans_davies_bouldin:' ,kmeans_davies_bouldin)
print('Evaluation criteria for Agglomerative Clustering :')
print('agg_silhoutte:' , agg_silhoutte)
print('agg_cainski_harabasz:' , agg_cainski_harabasz)
print('agg_davies_bouldin:' ,agg_davies_bouldin)
# Out:
# Evaluation criteria for Kmeans:
# kmeans_silhoutte: 0.6486437837860929
# kmeans_cainski_harabasz: 374.4673670902147
# kmeans_davies_bouldin: 0.4806565016508071
# Evaluation criteria for Agglomerative Clustering :
# agg_silhoutte: 0.6476255767693838
# agg_cainski_harabasz: 371.22280364751936
# agg_davies_bouldin: 0.4847315854970793
